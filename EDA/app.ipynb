# %% [markdown]
# Step 0: Imports and Reading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv('C:\\Users\\USER\\OneDrive\\Desktop\\PROJECTS\\Data-Science-Projects-2025\\EDA\\coaster_db.csv')

# %%
df.shape
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df = df[['coaster_name',
    # 'Length', 'Speed',
    'Location', 'Status',
    # 'Opening date',
    #   'Type',
    'Manufacturer',
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date',
#     'Opened', 
    # 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
        'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    object
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 110.5+ KB

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    datetime64[ns]
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 110.5+ KB

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df = df.rename(columns={
    'coaster_name': 'Coaster_Name',
    'opening_date_clean': 'Opening_Date_Clean',
    'opening_date_time' : 'Opening_Date_Time',
    'year_introduced': 'Year_Introduced',
    'opening_date_clean': 'Opening_Date_Clean',
    'speed_mph': 'Speed_Mph',
    'height_ft': 'Height_Ft',
    'longitiude': 'Longitude',
    'latitude': 'Latitude',
    'inversions_clean': 'Inversions_Clean',
    'Gforce_clean' : 'Gforce'})

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date_Clean  Speed_Mph  Height_Ft  Inversions_clean  Gforce
# ...

# %% [markdown]
# NaN VALUES CHECK

# %%
df.isna()
# Out:
#       Coaster_Name  Location  Status  Manufacturer  Year_Introduced  Latitude  \
# 0            False     False   False         False            False     False
# 1            False     False   False         False            False     False
# 2            False     False   False          True            False     False
# 3            False     False   False         False            False     False
# 4            False     False   False         False            False     False
# ...            ...       ...     ...           ...              ...       ...
# 1082         False     False    True         False            False      True
# 1083         False     False   False         False            False     False
# 1084         False     False    True         False            False      True
# 1085         False     False   False         False            False      True
# 1086         False     False   False         False            False      True
#
# ...

# %%
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# Year_Introduced         0
# Latitude              275
# longitude             275
# Type_Main               0
# Opening_Date_Clean    250
# Speed_Mph             150
# Height_Ft             916
# Inversions_clean        0
# Gforce                725
# dtype: int64

# %% [markdown]
# DUPLICATE CHECK

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, Latitude, longitude, Type_Main, Opening_Date_Clean, Speed_Mph, Height_Ft, Inversions_clean, Gforce]
# Index: []

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %% [markdown]
# TOTAL LOC'S OF ALL DUPLICATED VALUES OF COASTER_NAME COLUMN

# %%
df.loc[df.duplicated(subset='Coaster_Name')]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
df.loc[df.duplicated(subset='Coaster_Name')].head(3)
# Out:
#                    Coaster_Name            Location   Status  \
# 43        Crystal Beach Cyclone  Crystal Beach Park  Removed
# 60                  Derby Racer        Revere Beach  Removed
# 61  Blue Streak (Conneaut Lake)  Conneaut Lake Park   Closed
#
#           Manufacturer  Year_Introduced  Latitude  longitude Type_Main  \
# 43  Traver Engineering             1927   42.8617   -79.0598      Wood
# 60      Fred W. Pearce             1937   42.4200   -70.9860      Wood
# 61                 NaN             1938   41.6349   -80.3180      Wood
#
#    Opening_Date_Clean  Speed_Mph  Height_Ft  Inversions_clean  Gforce
# 43         1926-01-01       60.0        NaN                 0     4.0
# 60         1911-01-01        NaN        NaN                 0     NaN
# 61         1938-05-23       50.0        NaN                 0     NaN

# %% [markdown]
# CHECKING CRYSTAL BEACH CYCLONE

# %%
# Checking an example duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
#Year Interoduced is different for the same coaster name, so we will keep the first one
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  longitude Type_Main Opening_Date_Clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     Speed_Mph  Height_Ft  Inversions_clean  Gforce
# 39       60.0        NaN                 0     4.0
# 43       60.0        NaN                 0     4.0

# %%
df.loc[df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %% [markdown]
# WE HAVE TO DELETE ALL THIS DUPLICATE ROWS WHIC IS SEEN ABOVE

# %%
int(df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date_Clean']).sum())
# Out:
# 97

# %% [markdown]
# WHEN   (~	NOT	Inverts all the bits)  IS USED ALL THE ROWS ARE SELECTED WHICH ARE CORRECT(NOT DUPLICATED ROWS)

# %%
~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1082    False
# 1083     True
# 1084    False
# 1085     True
# 1086     True
# Length: 1087, dtype: bool

# %% [markdown]
# WE CREATE A NEW DF OF ALL THIS (NOT DUPLICATED VALUES) COREECT ROWS

# %%
df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])]
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1079            Ice Breaker (roller coaster)                SeaWorld Orlando
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %% [markdown]
# AS YOU CAN SEE BECAUSE THIS DF IS ONLY CORRECT ROWS, WE HAVE TO CORRECT ITS INDEXING

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date_Clean'])] \
.reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %% [markdown]
# Step 3: Feature Understanding¶
# (Univariate analysis)
#
# Plotting Feature Distributions
# Histogram
# KDE
# Boxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1952     1
# 1956     1
# 1961     1
# 1955     1
# 1959     1
# Name: count, Length: 101, dtype: int64

# %%
graphy = df['Year_Introduced'].value_counts() \
    .head(10) \
        .plot(kind='barh', title='Top 10 Years Introduced')
graphy.set_xlabel('Number of Coasters Introduced')
graphy.set_ylabel('Year Introduced')
graphy.set_title('Top 10 Years Introduced')
# Out:
# Text(0.5, 1.0, 'Top 10 Years Introduced')

# %% [markdown]
# SPEED MPH IS NAN A LOT IN THE START BUT HAS VALUES AFTERWARDS WE CAN SEE THAT FROM THE HISTOGRAM

# %%
griphy = df['Speed_Mph'].plot(kind='hist', bins=50, title ='Speed Distribution of Coasters')
griphy.set_xlabel('Speed (MPH)')
# Out:
# Text(0.5, 0, 'Speed (MPH)')

# %% [markdown]
# HISTOGRAM IS NOT VERY GOOD FOR THIS DATA SO WHY NOT USE (Kernel Density Estimate of Values)----->KDE

# %%
griphy = df['Speed_Mph'].plot(kind='kde', title ='KDE of Speed Distribution of Coasters')
griphy.set_xlabel('Speed (mph)')
plt.show()  # OnLY SHOWS GRAPH AND REMOVES THE TEXT UNNCESSARY WHCH ARE

# %% [markdown]
# Step 4: Feature Relationships
# Scatterplot
# Heatmap Correlation
# Pairplot
# Groupby comparisons

# %% [markdown]
# A scatterplot where there are no relationship between the columns

# %%
df.plot(kind='scatter', x='Speed_Mph', y='Height_Ft', title='Speed vs Height of Coasters')
plt.show()

# %% [markdown]
# USING SEABORN

# %%
seaborn_use_karneke_liyye = sns.scatterplot(data=df,
                                            x='Speed_Mph',
                                            y='Height_Ft',
                                            hue='Year_Introduced',
                                            palette='viridis',)

# %% [markdown]
# PAIRPLOT USING

# %%
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
sns.pairplot(df, vars=['Year_Introduced', 'Speed_Mph', 'Height_Ft', 'Inversions_clean'], hue='Type_Main')
plt.show()

# %%
df_corr = df[['Year_Introduced','Speed_Mph','Height_Ft','Inversions_clean','Gforce']].dropna().corr()
df_corr
# Out:
#                   Year_Introduced  Speed_Mph  Height_Ft  Inversions_clean  \
# Year_Introduced          1.000000   0.171978   0.135413         -0.209887
# Speed_Mph                0.171978   1.000000   0.733999         -0.028705
# Height_Ft                0.135413   0.733999   1.000000         -0.079736
# Inversions_clean        -0.209887  -0.028705  -0.079736          1.000000
# Gforce                   0.160247   0.607383   0.466482          0.275991
#
#                     Gforce
# Year_Introduced   0.160247
# Speed_Mph         0.607383
# Height_Ft         0.466482
# Inversions_clean  0.275991
# Gforce            1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <Axes: >

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_Mph'] \
    .agg(['mean','count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Coast Speed by Location')
ax.set_xlabel('Average Coaster Speed')
plt.show()
