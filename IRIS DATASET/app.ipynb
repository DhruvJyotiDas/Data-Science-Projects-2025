# %% [markdown]
# DATASET Information
# The data set contains 3 classes of 50 instances each , where each class refers to a different type of iris plant (Iris setosa, Iris virginica, and Iris versicolor). Each instance is described by 4 features: the length and the width of the sepals and petals.
#
# Attribiute Information:
#
# 1. sepal length in cm
# 2. sepal width in cm
# 3. petal length in cm
# 4. petal width in cm
# 5. class:-- Iris Stosa --Iris Versicolour --Iris Virginica

# %% [markdown]
# IMPORTANT MODULES :------>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %% [markdown]
# LOADING THE DATASET :---->

# %%
df = pd.read_csv('iris.csv')
print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Remove the 'Id' column
# This column is not needed for analysis and may contain redundant information.
df = df.drop(columns=['Id'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Display basic statistics of the dataset
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# Display information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Display the first few rows of the dataset
df.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# PREPROCESSING DATA :-------->>>>

# %%
#Checking Null Values

# %%
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# *ALL Histograms for all columns*

# %%
df['Species'].hist(bins=10, edgecolor='black')
# Out:
# <Axes: >

# %%
df['SepalLengthCm'].hist(bins=10, edgecolor='black')
# Out:
# <Axes: >

# %%
df['SepalWidthCm'].hist(bins=10, edgecolor='black')
# Out:
# <Axes: >

# %%
df['PetalLengthCm'].hist(bins=10, edgecolor='black')
# Out:
# <Axes: >

# %%
df['PetalWidthCm'].hist(bins=10, edgecolor='black')
# Out:
# <Axes: >

# %%
species = [ 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['red', 'green', 'blue']


for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], label=species[i])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend()
plt.title('Sepal Length vs Sepal Width')  
plt.show()

# %%
for i in range(3):
   x = df[df['Species'] == species[i]]
   plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], label=species[i]) 
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.legend()
plt.title('Petal Length vs Petal Width')
plt.show()

# %% [markdown]
# # Coorelation Matrix
# A correlation matrix is a table showing correlation coeeficients between variables. Each cell in the table shows the correlation between two variables. The value is in the range -1 to 1 . If two variables have high correlation, we can neglect oene v=variable from those two

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.corr(numeric_only=True)
# Display the correlation matrix using seaborn heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f',square=True, linewidths=0.5, cbar_kws={"shrink": 0.75})
plt.title('Correlation Matrix', fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %% [markdown]
# # Label Encounter
# In Machine learning, we usually deal with datsets which contains multiple labels in one or more than on column.These labels can be in the form of words or numbers. Label Encoding refers to converting the labels into numeric form so as to convert it into the machine - readable form.

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize the LabelEncoder
le = LabelEncoder()

# %%
# Encode the 'Species' column using LabelEncoder
# This will convert the categorical labels into numeric form, making it suitable for machine learning algorithms.
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# # Model Training

# %%
# Splitting Dataset into test and train

from sklearn.model_selection import train_test_split
# Split the dataset into features (X) and target variable (y)
# Train - 70% and Test - 30%
X = df.drop(columns=['Species'])
Y = df['Species']
# Split the dataset into training and testing sets
# Using a test size of 30% and a random state for reproducibility
x_train,x_test,y_train,y_test = train_test_split(X,Y, test_size = 0.30)
# Display the shapes of the training and testing sets
print("Training set shape:", x_train.shape, y_train.shape)
# Out:
# Training set shape: (105, 4) (105,)

# %% [markdown]
# **Trying Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# Train the model using the training data
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Accuracy of the model on the training set
print("Accuracy on training set:", model.score(x_train,y_train)*100)
# Out:
# Accuracy on training set: 97.14285714285714

# %% [markdown]
# **Trying K-Nearest Neighbours**

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy on traing set:", model.score(x_train,y_train)*100)
# Out:
# Accuracy on traing set: 95.23809523809523

# %% [markdown]
# **Trying Advanced Decision Trees**

# %%
from sklearn.tree import DecisionTreeClassifier
model  = DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy on traing set:", model.score(x_train,y_train)*100)
# Out:
# Accuracy on traing set: 100.0

# %%
sns.pairplot(df, vars=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], hue='Species')
plt.show()

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]
